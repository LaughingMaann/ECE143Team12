# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import functions as fu
df =pd. read_csv('vgsales.csv')
df = df[df['Year'] <= 2016]
df_EU=df.loc[:,['Year','Genre','EU_Sales']]
df_NA=df.loc[:,['Year','Genre','NA_Sales']]
df_JP=df.loc[:,['Year','Genre','JP_Sales']]
df_OT=df.loc[:,['Year','Genre','Other_Sales']]
df_GL=df.loc[:,['Year','Genre','Global_Sales']]


fu.plot(df_EU, 'EU sales vs. year of top 5 genres')
fu.plot(df_NA, 'NA sales vs. year of top 5 genres')
fu.plot(df_JP, 'JP sales vs. year of top 5 genres')
fu.plot(df_OT, 'Other sales vs. year of top 5 genres')
fu.plot(df_GL, 'Global sales vs. year of top 5 genres')

# %%
fu.compare(df)
